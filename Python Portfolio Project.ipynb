# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set_theme(font = 'Century Schoolbook')
mpg = sns.load_dataset('mpg')

# %% [markdown]
# # Create a visual showing the relationship between horsepower and fuel economy.

# %%
sns.relplot (data = mpg, x = 'horsepower', y = 'mpg', aspect = 1.5)
plt.title('Relationship Between Horsepower and Fuel Economy')
plt.xlabel('Horsepower')
plt.ylabel('Miles Per Gallon')
plt.style.use('seaborn-v0_8')

# %%
# There appears to be a common trend of a negative relationship between horsepower and fuel economy, where cars with higher horsepower generally tend to have worse fuel efficiency.

# %% [markdown]
# # Create a table summarizing fuel economy by country of origin.

# %%
mpg.groupby(['origin']).agg({'mpg':'mean'}).round(1).sort_values(by = 'mpg', ascending = False).reset_index().rename(columns = {'origin':'Country of Origin','mpg':'Average Miles Per Gallon'})
# Out:
#   Country of Origin  Average Miles Per Gallon
# 0             japan                      30.5
# 1            europe                      27.9
# 2               usa                      20.1

# %%
# Japan model cars have the best average fuel economy while USA has the worst on average.

# %% [markdown]
# # Create a visual showing how fuel economy has changed over time.

# %%
sns.relplot(data = mpg, x = 'model_year', y = 'mpg', kind = 'line',aspect = 1.5, errorbar = None)
plt.title('Change in Fuel Economy Over Time')
plt.xlabel('Model Year')
plt.ylabel('Average Miles Per Gallon')
# Out:
# Text(4.694444444444445, 0.5, 'Average Miles Per Gallon')

# %%
# "The average fuel economy showed a marked improvement between the 1979 and 1980 models.

# %% [markdown]
# # Create two other visuals or tables related to fuel economy.

# %%
mpg['Brand Name'] = mpg['name'].str.split().str[0].str.title()
mpg.groupby(['Brand Name']).agg({'mpg':'mean'}).round(1).reset_index().rename(columns = {'mpg':'Average Miles Per Gallon'}).sort_values(by = 'Average Miles Per Gallon',ascending = False)
# Out:
#        Brand Name  Average Miles Per Gallon
# 36             Vw                      39.0
# 21         Nissan                      36.0
# 32        Triumph                      35.0
# 15          Honda                      33.8
# 27        Renault                      32.9
# 10         Datsun                      31.1
# 17          Mazda                      30.9
# 29         Subaru                      30.5
# 33      Vokswagen                      29.8
# 34     Volkswagen                      29.1
# 12           Fiat                      28.9
# 30         Toyota                      28.4
# 1            Audi                      26.7
# 16          Maxda                      26.0
# 23           Opel                      25.8
# 18       Mercedes                      25.4
# 5           Capri                      25.0
# 28           Saab                      23.9
# 2             Bmw                      23.8
# 24        Peugeot                      23.7
# 19  Mercedes-Benz                      23.2
# 31        Toyouta                      23.0
# 11          Dodge                      22.1
# 25       Plymouth                      21.7
# 35          Volvo                      21.1
# 22     Oldsmobile                      21.1
# 7       Chevrolet                      20.5
# 26        Pontiac                      20.0
# 4        Cadillac                      19.8
# 13           Ford                      19.7
# 3           Buick                      19.2
# 20        Mercury                      19.1
# 0             Amc                      18.2
# 8           Chevy                      18.0
# 9        Chrysler                      17.3
# 6       Chevroelt                      16.0
# 14             Hi                       9.0

# %%
mpg_data = mpg.groupby(['Brand Name']).agg({'mpg':'mean'}).round(1).reset_index().rename(columns = {'mpg':'Average Miles Per Gallon'}).sort_values(by = 'Average Miles Per Gallon',ascending = True)
sns.catplot(data = mpg_data, y = 'Brand Name', x = 'Average Miles Per Gallon', kind = 'bar', height = 8, edgecolor = 'black')
plt.title('Average Miles Per Gallon by Brand Name')
plt.ylabel(None)
plt.xlabel(None)
# Out:
# Text(0.5, 33.00000000000003, '')

# %%
# If a person wants the most fuel efficient cars on average, the best car brand would be VW (Volkswagen).
